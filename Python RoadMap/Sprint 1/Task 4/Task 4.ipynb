# %% [markdown]
# # 1- Question
# 1-read you csv file (https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv )
#
# 2-print the first 5 rows
#
# 3-print the shape of the data
#
# 4- print and data type of each column

# %%
import pandas as pd 
file = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv"
df = pd.read_csv(file)
print("shape of the data" , df.shape)
print("print the first 5 rows ")
df.head()
# Out:
# shape of the data (53940, 10)
# print the first 5 rows
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
print("Data type of each column ")
df.dtypes
# Out:
# Data type of each column
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %% [markdown]
# # 2-Question
# 1- print carat column
#
# 2- Write a Pandas program to create a new 'Quality -color' Column (cut,color)
#
# examble => ( Ideal, E)

# %%
df.carat[:5] ## carat column only first 5 rows
# Out:
# 0    0.23
# 1    0.21
# 2    0.23
# 3    0.29
# 4    0.31
# Name: carat, dtype: float64

# %%
tmp = [(df.cut[i] , df.color[i]) for i in range(len(df))]
df['Quality -color'] = tmp
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#   Quality -color
# 0     (Ideal, E)
# 1   (Premium, E)
# 2      (Good, E)
# 3   (Premium, I)
# 4      (Good, J)

# %% [markdown]
# # 3-Question
# 1-Write a Pandas program to summarize the data.
#
# 2- only one column => 'table'
#
# 3- only 'float64' columns of the diamonds Dataframe. => include=['...']

# %%
print("To summarize the data" )
print(df.info())
# Out:
# To summarize the data
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
# carat             53940 non-null float64
# cut               53940 non-null object
# color             53940 non-null object
# clarity           53940 non-null object
# depth             53940 non-null float64
# table             53940 non-null float64
# price             53940 non-null int64
# x                 53940 non-null float64
# y                 53940 non-null float64
# z                 53940 non-null float64
# Quality -color    53940 non-null object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 4.5+ MB
# None

# %%
print("only print 'float64' columns of the diamonds Dataframe")
for i in df.columns:
    #print(df.dtypes[i])
    if df.dtypes[i] == 'float64':
        print(df[i][:3]) ### to only print thefirst 3 rows
        print( )
# Out:
# only print 'float64' columns of the diamonds Dataframe
# 0    0.23
# 1    0.21
# 2    0.23
# Name: carat, dtype: float64
#
# 0    61.5
# 1    59.8
# 2    56.9
# Name: depth, dtype: float64
#
# 0    55.0
# 1    61.0
# 2    65.0
# Name: table, dtype: float64
#
# 0    3.95
# 1    3.89
# 2    4.05
# Name: x, dtype: float64
#
# 0    3.98
# 1    3.84
# 2    4.07
# Name: y, dtype: float64
#
# 0    2.43
# 1    2.31
# 2    2.31
# Name: z, dtype: float64

# %%
print("print only table column")
df.table.head()
# Out:
# print only table column
# 0    55.0
# 1    61.0
# 2    65.0
# 3    58.0
# 4    58.0
# Name: table, dtype: float64

# %% [markdown]
# # 4-Question
# Write a Pandas program to find the details of the diamonds where length>5, width>5 and depth>5. (x,y,z)

# %%
df.loc[(df['x'] > 5) & (df['y'] >5) & (df['z'] >5)]
# Out:
#        carat        cut color clarity  depth  table  price     x      y  \
# 11778   1.83       Fair     J      I1   70.0   58.0   5083  7.34   7.28
# 13002   2.14       Fair     J      I1   69.4   57.0   5405  7.74   7.70
# 13118   2.15       Fair     J      I1   65.5   57.0   5430  8.01   7.95
# 13562   1.96       Fair     F      I1   66.6   60.0   5554  7.59   7.56
# 13757   2.22       Fair     J      I1   66.7   56.0   5607  8.04   8.02
# 13929   2.00       Fair     I      I1   66.0   60.0   5667  7.78   7.74
# 13991   2.01       Fair     I      I1   67.4   58.0   5696  7.71   7.64
# 14138   2.27       Fair     J      I1   67.6   55.0   5733  8.05   8.00
# 14504   1.81       Fair     J      I1   68.0   57.0   5859  7.43   7.39
# 14645   2.00       Fair     H      I1   69.8   54.0   5914  7.60   7.56
# 14881   1.82       Fair     H      I1   67.3   58.0   5993  7.50   7.47
# 14912   2.03       Fair     H      I1   64.4   59.0   6002  7.91   7.85
# ...

# %% [markdown]
# # 5-Question
# 1- rename one col
#
# 2- rename two col togeather
#
# 3- rename all col togeather

# %%
df_copy = df.copy()
print(" Rename only one column")
### to rename cut to quilty
df_copy.rename(columns = {'cut' :'Quilty'} , inplace = True)
df_copy.head()
# Out:
#  Rename only one column
#    carat   Quilty color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#   Quality -color
# 0     (Ideal, E)
# 1   (Premium, E)
# 2      (Good, E)
# 3   (Premium, I)
# 4      (Good, J)

# %%
print(" Rename only 2 columns ")
df_copy.rename(columns = {'x' :'X' , 'y':'Y'} , inplace = True)
df_copy.head()
# Out:
#  Rename only 2 columns
#    carat   Quilty color clarity  depth  table  price     X     Y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#   Quality -color
# 0     (Ideal, E)
# 1   (Premium, E)
# 2      (Good, E)
# 3   (Premium, I)
# 4      (Good, J)

# %%
print("Rename all columns ")
cols = ['Carat' , 'Quality' , 'Color' , 'Clarity' , 'Depth' , 'Table' , 'Price' , 'X' , 'Y' , 'Z' , 'Quality & Color']
df_copy.columns = cols
df_copy.head()
# Out:
# Rename all columns
#    Carat  Quality Color Clarity  Depth  Table  Price     X     Y     Z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#   Quality & Color
# 0      (Ideal, E)
# 1    (Premium, E)
# 2       (Good, E)
# 3    (Premium, I)
# 4       (Good, J)

# %% [markdown]
# # 6-Question
# Write a Pandas program to find the diamonds that are either Good or Very Good.

# %%
##df.cut.apply(lambda x : x == "Good" or x == "Very Good") ## as that will only print boolen result
df.loc[(df.cut == 'Good') | (df.cut == 'Very Good')]
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6       0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7       0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 9       0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10      0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 17      0.30       Good     J     SI1   63.4   54.0    351  4.23  4.29  2.70
# 18      0.30       Good     J     SI1   63.8   56.0    351  4.23  4.26  2.71
# 19      0.30  Very Good     J     SI1   62.7   59.0    351  4.21  4.27  2.66
# 20      0.30       Good     I     SI2   63.3   56.0    351  4.26  4.30  2.71
# ...

# %% [markdown]
# # 7-Question
# 1-print the name of all the columns
#
# 2- Mean of each column
#
# 3-Mean of each row of diamonds DataFrame:

# %%
print("Name of all the columns are : " )
df.columns
# Out:
# Name of all the columns are :
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z', 'Quality -color'],
#       dtype='object')

# %%
for i in df.columns:
    #print(df.dtypes[i])
    if df.dtypes[i] == 'float64' or df.dtypes[i] == 'int64' :
        print(" Mean of {col} Column is {m}".format(col = i , m = df[i].mean()))
# Out:
#  Mean of carat Column is 0.7979397478679852
#  Mean of depth Column is 61.74940489432624
#  Mean of table Column is 57.45718390804603
#  Mean of price Column is 3932.799721913237
#  Mean of x Column is 5.731157211716609
#  Mean of y Column is 5.734525954764462
#  Mean of z Column is 3.5387337782723316

# %%
print("Mean of each row ")
for i in df.columns:
    #print(df.dtypes[i])
    if df.dtypes[i] == 'float64' or df.dtypes[i] == 'int64' :
        print(df[i].mean)
# Out:
# Mean of each row
# <bound method Series.mean of 0        0.23
# 1        0.21
# 2        0.23
# 3        0.29
# 4        0.31
# 5        0.24
# 6        0.24
# 7        0.26
# 8        0.22
# 9        0.23
# 10       0.30
# 11       0.23
# 12       0.22
# 13       0.31
# 14       0.20
# 15       0.32
# 16       0.30
# 17       0.30
# 18       0.30
# 19       0.30
# 20       0.30
# 21       0.23
# 22       0.23
# 23       0.31
# 24       0.31
# 25       0.23
# 26       0.24
# 27       0.30
# 28       0.23
# 29       0.23
#          ...
# 53910    0.70
# 53911    0.57
# 53912    0.61
# 53913    0.80
# 53914    0.84
# 53915    0.77
# 53916    0.74
# 53917    0.90
# 53918    0.76
# 53919    0.76
# 53920    0.70
# 53921    0.70
# 53922    0.70
# 53923    0.73
# 53924    0.73
# 53925    0.79
# 53926    0.71
# 53927    0.79
# 53928    0.79
# 53929    0.71
# 53930    0.71
# 53931    0.71
# 53932    0.70
# 53933    0.70
# 53934    0.72
# 53935    0.72
# 53936    0.72
# 53937    0.70
# ...

# %% [markdown]
# # 8-Question
# 1- mean of 'price' column only
#
# 2- Write a Pandas program to calculate the mean of price for each cut of diamonds DataFrame.
#
# 3-Write a Pandas program to calculate count, minimum, maximum price for each cut of diamonds DataFrame.
#
# 4- count how many times each value in cut series of diamonds DataFrame occurs. value_counts()

# %%
print('Mean of price column only is ' , df.price.mean())
# Out:
# Mean of price column only is  3932.799721913237

# %%
value_count = df.cut.value_counts()
print("How many times each value in cut series occurs. ")
value_count.Ideal
reviews = pd.read_csv("../input/wine-reviews/winemag-data-130k-v2.csv", index_col=0)
reviews.head()
# Out:
# How many times each value in cut series occurs.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-2fb5d679a89b> in <module>()
#       2 print("How many times each value in cut series occurs. ")
#       3 value_count.Ideal
# ----> 4 reviews = pd.read_csv("../input/wine-reviews/winemag-data-130k-v2.csv", index_col=0)
#       5 reviews.head()
#
# ...

# %%
for i in dict(value_count):
   # print(df.loc[df.cut ==i]['price'].mean())
    print("Mean of {col} type is {m}".format(col = i , m =df.loc[df.cut ==i]['price'].mean()))
# Out:
# Mean of Ideal type is 3457.541970210199
# Mean of Premium type is 4584.2577042999055
# Mean of Very Good type is 3981.7598907465654
# Mean of Good type is 3928.864451691806
# Mean of Fair type is 4358.757763975155

# %%
for i in dict(value_count):
    print("Min value of  {col} type is {m}".format(col = i , m = df.loc[df.cut ==i]['price'].min()))
    print("Max value of  {col} type is {m}".format(col = i , m = df.loc[df.cut ==i]['price'].max()))
    print()
# Out:
# Min value of  Ideal type is 326
# Max value of  Ideal type is 18806
#
# Min value of  Premium type is 326
# Max value of  Premium type is 18823
#
# Min value of  Very Good type is 336
# Max value of  Very Good type is 18818
#
# Min value of  Good type is 327
# Max value of  Good type is 18788
#
# Min value of  Fair type is 337
# Max value of  Fair type is 18574

# %% [markdown]
# # 9-Question
# Write a Pandas program to count the number of missing values in each Series of diamonds DataFrame.

# %%
print("Number of missing values in each Series : ")
df.isnull().sum()
# Out:
# Number of missing values in each Series :
# carat             0
# cut               0
# color             0
# clarity           0
# depth             0
# table             0
# price             0
# x                 0
# y                 0
# z                 0
# Quality -color    0
# dtype: int64
